# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/sesilipirtskhalava/frangieh-dataset/frangieh.h5ad

# %% [markdown]
# ## GEARS benchmark — frangieh control dataset
#
# Evaluates GEARS against a simple average-perturbation baseline on the Frangieh control single-gene perturbation dataset.
#
# - Dataset: ~27 077 cells · 5 124 genes · 212 single-gene perturbations
# - Task: predict gene expression for held-out single-gene perturbations
# - Split: random 143 / 16 / 53 train / val / test across perturbations

# %% [markdown]
# ## 1. Environment setup

# %%
# %%capture
# Install required packages (output suppressed)
# !pip install -q scanpy python-igraph louvain
# !pip install -q torch-geometric anndata pytorch-lightning
# !pip install -q cell-gears

# %%
import scanpy as sc
import random
import numpy as np
import pandas as pd
import torch
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# Compatibility patch required by some GEARS versions
pd.Series.nonzero = lambda self: self.to_numpy().nonzero()

from gears import PertData, GEARS

# ── Reproducibility ──────────────────────────────────────────────────────────
SEED = 1
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"PyTorch {torch.__version__} | GPU available: {torch.cuda.is_available()} | device: {DEVICE}")
# Out:
# PyTorch 2.10.0+cu128 | GPU available: True | device: cuda

# %% [markdown]
# ## 2. Loading the data and processing

# %%
from gears import PertData

pert_data = PertData("./data")

pert_data.adata = sc.read_h5ad(
    "/kaggle/input/datasets/sesilipirtskhalava/frangieh-dataset/frangieh.h5ad"
)

print(pert_data.adata)
# Out:
# Downloading...
# 100%|██████████| 9.46M/9.46M [00:00<00:00, 16.9MiB/s]
# AnnData object with n_obs × n_vars = 110188 × 5124
#     obs: 'gene', 'condition', 'perturbation', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_5000'
#     uns: 'hvg', 'log1p'
#     layers: 'counts', 'logNor'

# %%
adata = pert_data.adata

control_adata = adata[
    adata.obs["condition"] == "Control"
].copy()

coculture_adata = adata[
    adata.obs["condition"] == "Co-culture"
].copy()

ifng_adata = adata[
    adata.obs["condition"] == "IFNγ"
].copy()

# %%
for name, ad in {
    "IFNg": ifng_adata,
    "Co-culture": coculture_adata,
    "Control": control_adata
}.items():

    print("\n", name)
    print("Cells:", ad.n_obs)
    print("Genes:", ad.n_vars)
    print("Perturbations:", ad.obs["perturbation"].nunique())
# Out:
#  IFNg
# Cells: 43432
# Genes: 5124
# Perturbations: 212
#
#  Co-culture
# Cells: 39679
# Genes: 5124
# Perturbations: 212
#
#  Control
# Cells: 27077
# Genes: 5124
# Perturbations: 212

# %%
# Keeping only control context
adata = pert_data.adata.copy()

control_adata = adata[
    adata.obs["condition"] == "Control"
].copy()

print(control_adata.shape)
print(control_adata.obs["condition"].value_counts())
print(control_adata.obs["gene"].value_counts().head())
# Out:
# (27077, 5124)
# condition
# Control    27077
# Name: count, dtype: int64
# gene
# CTRL       480
# NT5E       190
# RTP4       189
# TSC22D3    187
# TTLL1      186
# Name: count, dtype: int64

# %%
# Adding gene_name column required by GEARS
control_adata.var["gene_name"] = control_adata.var_names.astype(str)

print(control_adata.var.columns)
print(control_adata.var[["gene_name"]].head())
# Out:
# Index(['highly_variable', 'means', 'dispersions', 'dispersions_norm',
#        'highly_variable_5000', 'gene_name'],
#       dtype='object')
#           gene_name
# gene_name
# STK36         STK36
# TMEM45A     TMEM45A
# CLIP2         CLIP2
# GNAI3         GNAI3
# MRI1           MRI1

# %%
# GEARS expects obs["condition"] = perturbation identity
control_adata.obs["condition"] = control_adata.obs["perturbation"].astype(str)

# GEARS expects control to be named ctrl
control_adata.obs["condition"] = control_adata.obs["condition"].replace({
    "control": "ctrl",
    "Control": "ctrl",
    "CTRL": "ctrl"
})

# GEARS requires cell_type column
control_adata.obs["cell_type"] = "melanoma_control"

print(control_adata.obs[["perturbation", "condition", "cell_type"]].head())
print(control_adata.obs["condition"].value_counts().head())
# Out:
#               perturbation condition         cell_type
# Cell_barcodes
# CELL_55512             A2M       A2M  melanoma_control
# CELL_41384             A2M       A2M  melanoma_control
# CELL_35083             A2M       A2M  melanoma_control
# CELL_38432             A2M       A2M  melanoma_control
# CELL_34100             A2M       A2M  melanoma_control
# condition
# ctrl       480
# NT5E       190
# RTP4       189
# TSC22D3    187
# FGFR1      186
# Name: count, dtype: int64

# %%
from scipy import sparse

if not sparse.issparse(control_adata.X):
    control_adata.X = sparse.csr_matrix(control_adata.X)

print(type(control_adata.X))
# Out:
# <class 'scipy.sparse._csr.csr_matrix'>

# %%
pert_data_frangieh = PertData("./data")

pert_data_frangieh.new_data_process(
    dataset_name="frangieh_control_de_sparse",
    adata=control_adata,
    skip_calc_de=False
)
# Out:
# Found local copy...
# Downloading...
# 100%|██████████| 559k/559k [00:00<00:00, 1.51MiB/s]
# Creating pyg object for each cell in the data...
# Creating dataset file...
#   0%|          | 0/212 [00:00<?, ?it/s]
# A2M
#   1%|          | 2/212 [00:01<02:07,  1.64it/s]
# ACTA2
#   3%|▎         | 6/212 [00:04<02:57,  1.16it/s]
# APOD
#   4%|▍         | 9/212 [00:07<02:40,  1.27it/s]
# ATP1B1
#   6%|▌         | 12/212 [00:09<02:27,  1.36it/s]
# BOLA2B
#   7%|▋         | 15/212 [00:11<02:23,  1.37it/s]
# C6orf226
#   8%|▊         | 16/212 [00:12<02:20,  1.39it/s]
# C19orf48
#  10%|▉         | 21/212 [00:15<01:43,  1.85it/s]
# CD44
#  13%|█▎        | 27/212 [00:20<02:19,  1.33it/s]
# CD274
#  14%|█▎        | 29/212 [00:21<01:50,  1.65it/s]
# CDH19
#  16%|█▌        | 33/212 [00:24<02:03,  1.45it/s]
# CDKN2A
#  16%|█▌        | 34/212 [00:25<02:29,  1.19it/s]
# CDKN2B
#  19%|█▉        | 40/212 [00:30<02:16,  1.26it/s]
# CSPG4
#  22%|██▏       | 47/212 [00:35<02:08,  1.28it/s]
# CTSO
#  23%|██▎       | 48/212 [00:36<02:15,  1.21it/s]
# CXCR4
#  23%|██▎       | 49/212 [00:36<02:03,  1.32it/s]
# CYP27A1
#  29%|██▉       | 61/212 [00:43<01:01,  2.46it/s]
# EMP1
#  29%|██▉       | 62/212 [00:44<01:20,  1.87it/s]
# ENPP1
#  30%|██▉       | 63/212 [00:44<01:31,  1.62it/s]
# EVA1A
#  31%|███       | 65/212 [00:45<01:17,  1.89it/s]
# FBXO32
#  32%|███▏      | 68/212 [00:48<01:42,  1.40it/s]
# FMN1
#  33%|███▎      | 71/212 [00:50<01:25,  1.65it/s]
# FRZB
#  36%|███▋      | 77/212 [00:53<01:01,  2.21it/s]
# GPNMB
#  38%|███▊      | 80/212 [00:55<01:29,  1.47it/s]
# HLA-A
#  39%|███▉      | 83/212 [00:57<01:26,  1.50it/s]
# HLA-DRB5
#  40%|████      | 85/212 [00:59<01:29,  1.41it/s]
# HLA-F
#  42%|████▏     | 88/212 [01:01<01:12,  1.71it/s]
# HSPA1A
#  45%|████▌     | 96/212 [01:07<01:19,  1.46it/s]
# ITGA3
#  47%|████▋     | 99/212 [01:09<01:31,  1.24it/s]
# JMJD7
#  48%|████▊     | 101/212 [01:11<01:29,  1.25it/s]
# KDR
#  50%|████▉     | 105/212 [01:14<01:30,  1.19it/s]
# LGALS3
#  50%|█████     | 106/212 [01:15<01:27,  1.22it/s]
# LGALS3BP
#  51%|█████     | 108/212 [01:17<01:22,  1.25it/s]
# LY96
#  51%|█████▏    | 109/212 [01:17<01:19,  1.30it/s]
# MC1R
#  53%|█████▎    | 112/212 [01:20<01:21,  1.22it/s]
# MIA
#  56%|█████▌    | 119/212 [01:22<00:33,  2.82it/s]
# NGFR
#  57%|█████▋    | 121/212 [01:24<00:45,  1.98it/s]
# NMRK1
#  59%|█████▉    | 126/212 [01:27<00:58,  1.46it/s]
# NSG1
#  60%|█████▉    | 127/212 [01:28<01:01,  1.39it/s]
# NT5E
#  63%|██████▎   | 134/212 [01:32<00:40,  1.92it/s]
# PIK3IP1
#  68%|██████▊   | 145/212 [01:38<00:50,  1.34it/s]
# RBP7
#  71%|███████   | 151/212 [01:41<00:23,  2.65it/s]
# RTP4
#  73%|███████▎  | 154/212 [01:43<00:27,  2.09it/s]
# S100B
#  76%|███████▌  | 161/212 [01:48<00:40,  1.25it/s]
# SERPINA3
#  76%|███████▋  | 162/212 [01:49<00:38,  1.31it/s]
# SERPINE2
#  80%|███████▉  | 169/212 [01:54<00:30,  1.41it/s]
# SLC22A18
#  81%|████████  | 171/212 [01:56<00:32,  1.27it/s]
# SLC26A2
#  84%|████████▍ | 178/212 [02:01<00:24,  1.39it/s]
# SPESP1
#  84%|████████▍ | 179/212 [02:02<00:25,  1.31it/s]
# SPINT1
#  85%|████████▌ | 181/212 [02:03<00:22,  1.39it/s]
# ST6GALNAC2
#  88%|████████▊ | 187/212 [02:07<00:18,  1.36it/s]
# TAPBPL
#  91%|█████████ | 192/212 [02:11<00:15,  1.32it/s]
# TIMP2
#  91%|█████████ | 193/212 [02:12<00:13,  1.38it/s]
# TIMP3
#  92%|█████████▏| 194/212 [02:12<00:12,  1.43it/s]
# TM4SF1
#  94%|█████████▍| 200/212 [02:16<00:06,  1.72it/s]
# TRIM22
#  95%|█████████▍| 201/212 [02:17<00:06,  1.64it/s]
# TSC22D3
#  95%|█████████▌| 202/212 [02:18<00:07,  1.39it/s]
# TTLL1
#  97%|█████████▋| 205/212 [02:20<00:04,  1.51it/s]
# UCN2
# 100%|██████████| 212/212 [02:24<00:00,  1.47it/s]
# Done!
# Saving new dataset pyg object at ./data/frangieh_control_de_sparse/data_pyg/cell_graphs.pkl
# Done!

# %% [markdown]
# ## 3. Train / val / test split

# %%
# Creating perturbation-level split
all_perturbations = sorted([
    p for p in control_adata.obs["condition"].unique()
    if p != "ctrl"
])

train_val_perturbations, test_perturbations = train_test_split(
    all_perturbations,
    test_size=0.25,
    random_state=SEED,
    shuffle=True
)

train_perturbations, val_perturbations = train_test_split(
    train_val_perturbations,
    test_size=0.1,
    random_state=SEED,
    shuffle=True
)

print("Total perturbations:", len(all_perturbations))
print("Train:", len(train_perturbations))
print("Val:", len(val_perturbations))
print("Test:", len(test_perturbations))
# Out:
# Total perturbations: 211
# Train: 142
# Val: 16
# Test: 53

# %%
# Assigning manual perturbation-level split to GEARS
pert_data_frangieh.split = "manual_random_single_pert"

pert_data_frangieh.set2conditions = {
    "train": train_perturbations + ["ctrl"],
    "val": val_perturbations,
    "test": test_perturbations,
}

print(pert_data_frangieh.set2conditions.keys())
print("Train example:", pert_data_frangieh.set2conditions["train"][:5])
print("Val example:", pert_data_frangieh.set2conditions["val"][:5])
print("Test example:", pert_data_frangieh.set2conditions["test"][:5])
# Out:
# dict_keys(['train', 'val', 'test'])
# Train example: ['HLA-B', 'CITED1', 'MT2A', 'CD58', 'VAT1']
# Val example: ['DLL3', 'DDX17', 'SMAD4', 'ILF2', 'P2RX4']
# Test example: ['CTSB', 'TGFB1', 'DDR1', 'TPRKB', 'CHCHD2']

# %%
import pickle

split_dict_path = "./data/frangieh_control_manual_split.pkl"

with open(split_dict_path, "wb") as f:
    pickle.dump(pert_data_frangieh.set2conditions, f)

print(split_dict_path)
# Out:
# ./data/frangieh_control_manual_split.pkl

# %%
# Preparing GEARS split
pert_data_frangieh.prepare_split(
    split="custom",
    seed=SEED,
    split_dict_path=split_dict_path
)

pert_data_frangieh.get_dataloader(
    batch_size=32,
    test_batch_size=32
)
# Out:
# Creating dataloaders....
# Done!

# %% [markdown]
# ## 4. Ground-truth centroids and baseline

# %%
# Ground-truth centroids and average perturbation baseline

X = control_adata.X.toarray() if hasattr(control_adata.X, "toarray") else control_adata.X

gene_names = control_adata.var_names
conditions = control_adata.obs["condition"].values

pert_mask = conditions != "ctrl"

df_pert = pd.DataFrame(
    X[pert_mask],
    columns=gene_names
)

df_pert["condition"] = conditions[pert_mask]

ground_truth_centroids = (
    df_pert.groupby("condition")[gene_names]
    .mean()
)

# Reference / baseline = average of training perturbation centroids
reference = ground_truth_centroids.loc[train_perturbations].mean(axis=0).values

print("Ground-truth centroids:", ground_truth_centroids.shape)
print("Reference vector shape:", reference.shape)
# Out:
# Ground-truth centroids: (212, 5124)
# Reference vector shape: (5124,)

# %% [markdown]
# ## 5. Train GEARS

# %%
gears_model = GEARS(
    pert_data_frangieh,
    device=DEVICE
)

gears_model.model_initialize(
    hidden_size=64
)
# Out:
# Downloading...
# 100%|██████████| 60.7M/60.7M [00:02<00:00, 25.4MiB/s]
# Extracting tar file...
# Done!

# %%
gears_model.train(
    epochs=20
)
# Out:
# Start Training...
# Epoch 1 Step 1 Train Loss: 1.1093
# Epoch 1 Step 51 Train Loss: 1.1660
# Epoch 1 Step 101 Train Loss: 1.2005
# Epoch 1 Step 151 Train Loss: 1.1178
# Epoch 1 Step 201 Train Loss: 1.1841
# Epoch 1 Step 251 Train Loss: 1.0784
# Epoch 1 Step 301 Train Loss: 1.1964
# Epoch 1 Step 351 Train Loss: 1.0668
# Epoch 1 Step 401 Train Loss: 1.0071
# Epoch 1 Step 451 Train Loss: 1.1942
# Epoch 1 Step 501 Train Loss: 1.0049
# Epoch 1 Step 551 Train Loss: 1.2177
# Epoch 1: Train Overall MSE: 0.0054 Validation Overall MSE: 0.0048.
# Train Top 20 DE MSE: 0.0191 Validation Top 20 DE MSE: 0.0158.
# Epoch 2 Step 1 Train Loss: 1.0881
# Epoch 2 Step 51 Train Loss: 1.1395
# Epoch 2 Step 101 Train Loss: 1.1033
# Epoch 2 Step 151 Train Loss: 1.0005
# Epoch 2 Step 201 Train Loss: 0.9278
# Epoch 2 Step 251 Train Loss: 1.2096
# Epoch 2 Step 301 Train Loss: 1.1518
# Epoch 2 Step 351 Train Loss: 1.0505
# Epoch 2 Step 401 Train Loss: 1.2123
# Epoch 2 Step 451 Train Loss: 1.1266
# Epoch 2 Step 501 Train Loss: 1.1038
# Epoch 2 Step 551 Train Loss: 1.0538
# Epoch 2: Train Overall MSE: 0.0046 Validation Overall MSE: 0.0045.
# Train Top 20 DE MSE: 0.0178 Validation Top 20 DE MSE: 0.0158.
# Epoch 3 Step 1 Train Loss: 1.1334
# Epoch 3 Step 51 Train Loss: 1.0232
# Epoch 3 Step 101 Train Loss: 1.2229
# Epoch 3 Step 151 Train Loss: 1.1016
# Epoch 3 Step 201 Train Loss: 1.0569
# Epoch 3 Step 251 Train Loss: 1.0702
# Epoch 3 Step 301 Train Loss: 1.1041
# Epoch 3 Step 351 Train Loss: 1.1554
# Epoch 3 Step 401 Train Loss: 1.0715
# Epoch 3 Step 451 Train Loss: 1.1336
# Epoch 3 Step 501 Train Loss: 1.0027
# Epoch 3 Step 551 Train Loss: 0.9830
# Epoch 3: Train Overall MSE: 0.3048 Validation Overall MSE: 0.3052.
# Train Top 20 DE MSE: 0.3715 Validation Top 20 DE MSE: 0.3880.
# Epoch 4 Step 1 Train Loss: 1.1582
# Epoch 4 Step 51 Train Loss: 1.0943
# Epoch 4 Step 101 Train Loss: 1.1166
# Epoch 4 Step 151 Train Loss: 1.1087
# Epoch 4 Step 201 Train Loss: 1.1447
# Epoch 4 Step 251 Train Loss: 0.9860
# Epoch 4 Step 301 Train Loss: 1.0790
# Epoch 4 Step 351 Train Loss: 1.1838
# Epoch 4 Step 401 Train Loss: 1.1202
# Epoch 4 Step 451 Train Loss: 1.0631
# Epoch 4 Step 501 Train Loss: 1.0648
# Epoch 4 Step 551 Train Loss: 1.0459
# Epoch 4: Train Overall MSE: 0.0042 Validation Overall MSE: 0.0043.
# Train Top 20 DE MSE: 0.0174 Validation Top 20 DE MSE: 0.0158.
# Epoch 5 Step 1 Train Loss: 1.0960
# Epoch 5 Step 51 Train Loss: 1.2502
# Epoch 5 Step 101 Train Loss: 1.2504
# Epoch 5 Step 151 Train Loss: 1.2848
# Epoch 5 Step 201 Train Loss: 1.1133
# Epoch 5 Step 251 Train Loss: 1.1921
# Epoch 5 Step 301 Train Loss: 1.1629
# Epoch 5 Step 351 Train Loss: 1.2247
# Epoch 5 Step 401 Train Loss: 1.1861
# Epoch 5 Step 451 Train Loss: 1.0628
# Epoch 5 Step 501 Train Loss: 0.9976
# Epoch 5 Step 551 Train Loss: 1.1258
# Epoch 5: Train Overall MSE: 0.0050 Validation Overall MSE: 0.0051.
# Train Top 20 DE MSE: 0.0181 Validation Top 20 DE MSE: 0.0169.
# Epoch 6 Step 1 Train Loss: 1.0824
# Epoch 6 Step 51 Train Loss: 1.1022
# Epoch 6 Step 101 Train Loss: 1.0657
# Epoch 6 Step 151 Train Loss: 1.1094
# Epoch 6 Step 201 Train Loss: 1.0094
# Epoch 6 Step 251 Train Loss: 1.0741
# Epoch 6 Step 301 Train Loss: 1.0401
# Epoch 6 Step 351 Train Loss: 1.1861
# Epoch 6 Step 401 Train Loss: 1.3044
# Epoch 6 Step 451 Train Loss: 1.1531
# Epoch 6 Step 501 Train Loss: 1.1143
# Epoch 6 Step 551 Train Loss: 1.0440
# Epoch 6: Train Overall MSE: 0.0041 Validation Overall MSE: 0.0042.
# Train Top 20 DE MSE: 0.0174 Validation Top 20 DE MSE: 0.0157.
# Epoch 7 Step 1 Train Loss: 0.9245
# Epoch 7 Step 51 Train Loss: 1.0283
# Epoch 7 Step 101 Train Loss: 1.0816
# Epoch 7 Step 151 Train Loss: 1.0632
# Epoch 7 Step 201 Train Loss: 1.2334
# Epoch 7 Step 251 Train Loss: 1.1641
# Epoch 7 Step 301 Train Loss: 1.0971
# Epoch 7 Step 351 Train Loss: 1.0762
# Epoch 7 Step 401 Train Loss: 1.1942
# Epoch 7 Step 451 Train Loss: 1.0357
# Epoch 7 Step 501 Train Loss: 1.1927
# Epoch 7 Step 551 Train Loss: 1.0491
# Epoch 7: Train Overall MSE: 0.0041 Validation Overall MSE: 0.0042.
# Train Top 20 DE MSE: 0.0174 Validation Top 20 DE MSE: 0.0157.
# Epoch 8 Step 1 Train Loss: 1.0481
# Epoch 8 Step 51 Train Loss: 1.0393
# Epoch 8 Step 101 Train Loss: 1.0393
# Epoch 8 Step 151 Train Loss: 1.1158
# Epoch 8 Step 201 Train Loss: 1.0345
# Epoch 8 Step 251 Train Loss: 1.1687
# Epoch 8 Step 301 Train Loss: 1.1161
# Epoch 8 Step 351 Train Loss: 1.1003
# Epoch 8 Step 401 Train Loss: 1.0534
# Epoch 8 Step 451 Train Loss: 1.1125
# Epoch 8 Step 501 Train Loss: 1.1354
# Epoch 8 Step 551 Train Loss: 1.1167
# Epoch 8: Train Overall MSE: 0.0041 Validation Overall MSE: 0.0042.
# Train Top 20 DE MSE: 0.0173 Validation Top 20 DE MSE: 0.0157.
# Epoch 9 Step 1 Train Loss: 1.0553
# Epoch 9 Step 51 Train Loss: 0.9710
# Epoch 9 Step 101 Train Loss: 1.1204
# Epoch 9 Step 151 Train Loss: 1.0533
# Epoch 9 Step 201 Train Loss: 0.9819
# Epoch 9 Step 251 Train Loss: 1.0342
# Epoch 9 Step 301 Train Loss: 1.1776
# Epoch 9 Step 351 Train Loss: 1.1552
# Epoch 9 Step 401 Train Loss: 1.1112
# Epoch 9 Step 451 Train Loss: 1.2873
# Epoch 9 Step 501 Train Loss: 1.0837
# Epoch 9 Step 551 Train Loss: 1.1220
# Epoch 9: Train Overall MSE: 0.0041 Validation Overall MSE: 0.0042.
# Train Top 20 DE MSE: 0.0173 Validation Top 20 DE MSE: 0.0157.
# Epoch 10 Step 1 Train Loss: 1.1401
# Epoch 10 Step 51 Train Loss: 1.0603
# Epoch 10 Step 101 Train Loss: 1.1121
# Epoch 10 Step 151 Train Loss: 0.9594
# Epoch 10 Step 201 Train Loss: 1.1730
# Epoch 10 Step 251 Train Loss: 1.1863
# Epoch 10 Step 301 Train Loss: 1.0652
# Epoch 10 Step 351 Train Loss: 1.0542
# Epoch 10 Step 401 Train Loss: 1.0681
# Epoch 10 Step 451 Train Loss: 1.1086
# Epoch 10 Step 501 Train Loss: 1.0760
# Epoch 10 Step 551 Train Loss: 1.1118
# Epoch 10: Train Overall MSE: 0.0041 Validation Overall MSE: 0.0042.
# Train Top 20 DE MSE: 0.0173 Validation Top 20 DE MSE: 0.0157.
# Epoch 11 Step 1 Train Loss: 1.0003
# Epoch 11 Step 51 Train Loss: 1.0621
# Epoch 11 Step 101 Train Loss: 1.1430
# Epoch 11 Step 151 Train Loss: 1.1444
# Epoch 11 Step 201 Train Loss: 1.1135
# Epoch 11 Step 251 Train Loss: 1.0868
# Epoch 11 Step 301 Train Loss: 1.2000
# Epoch 11 Step 351 Train Loss: 1.0971
# Epoch 11 Step 401 Train Loss: 1.1099
# Epoch 11 Step 451 Train Loss: 1.0688
# Epoch 11 Step 501 Train Loss: 1.0809
# Epoch 11 Step 551 Train Loss: 1.4409
# Epoch 11: Train Overall MSE: 0.0041 Validation Overall MSE: 0.0042.
# Train Top 20 DE MSE: 0.0173 Validation Top 20 DE MSE: 0.0157.
# Epoch 12 Step 1 Train Loss: 1.1812
# Epoch 12 Step 51 Train Loss: 1.0574
# Epoch 12 Step 101 Train Loss: 1.1592
# Epoch 12 Step 151 Train Loss: 1.1337
# Epoch 12 Step 201 Train Loss: 1.1731
# Epoch 12 Step 251 Train Loss: 1.0320
# Epoch 12 Step 301 Train Loss: 1.0908
# Epoch 12 Step 351 Train Loss: 1.0849
# Epoch 12 Step 401 Train Loss: 1.0070
# Epoch 12 Step 451 Train Loss: 1.0227
# Epoch 12 Step 501 Train Loss: 1.2425
# Epoch 12 Step 551 Train Loss: 1.1230
# Epoch 12: Train Overall MSE: 0.0041 Validation Overall MSE: 0.0042.
# Train Top 20 DE MSE: 0.0173 Validation Top 20 DE MSE: 0.0157.
# Epoch 13 Step 1 Train Loss: 1.1721
# Epoch 13 Step 51 Train Loss: 1.2945
# Epoch 13 Step 101 Train Loss: 1.2703
# Epoch 13 Step 151 Train Loss: 1.1557
# Epoch 13 Step 201 Train Loss: 1.0864
# Epoch 13 Step 251 Train Loss: 0.9214
# Epoch 13 Step 301 Train Loss: 1.0140
# Epoch 13 Step 351 Train Loss: 1.2342
# Epoch 13 Step 401 Train Loss: 1.0347
# Epoch 13 Step 451 Train Loss: 1.1029
# Epoch 13 Step 501 Train Loss: 1.0391
# Epoch 13 Step 551 Train Loss: 1.0498
# Epoch 13: Train Overall MSE: 0.0041 Validation Overall MSE: 0.0042.
# Train Top 20 DE MSE: 0.0174 Validation Top 20 DE MSE: 0.0157.
# Epoch 14 Step 1 Train Loss: 1.1966
# Epoch 14 Step 51 Train Loss: 1.0533
# Epoch 14 Step 101 Train Loss: 1.1000
# Epoch 14 Step 151 Train Loss: 1.1537
# Epoch 14 Step 201 Train Loss: 1.0833
# Epoch 14 Step 251 Train Loss: 1.0356
# Epoch 14 Step 301 Train Loss: 1.0505
# Epoch 14 Step 351 Train Loss: 1.0702
# Epoch 14 Step 401 Train Loss: 0.9460
# Epoch 14 Step 451 Train Loss: 1.1587
# Epoch 14 Step 501 Train Loss: 1.3489
# Epoch 14 Step 551 Train Loss: 1.1220
# Epoch 14: Train Overall MSE: 0.0040 Validation Overall MSE: 0.0042.
# Train Top 20 DE MSE: 0.0173 Validation Top 20 DE MSE: 0.0157.
# Epoch 15 Step 1 Train Loss: 1.3056
# Epoch 15 Step 51 Train Loss: 1.1646
# Epoch 15 Step 101 Train Loss: 0.9683
# Epoch 15 Step 151 Train Loss: 1.1174
# Epoch 15 Step 201 Train Loss: 1.0989
# Epoch 15 Step 251 Train Loss: 1.2015
# Epoch 15 Step 301 Train Loss: 1.0201
# Epoch 15 Step 351 Train Loss: 1.1978
# Epoch 15 Step 401 Train Loss: 1.1228
# Epoch 15 Step 451 Train Loss: 0.9870
# Epoch 15 Step 501 Train Loss: 1.0639
# Epoch 15 Step 551 Train Loss: 1.1786
# Epoch 15: Train Overall MSE: 0.0041 Validation Overall MSE: 0.0042.
# Train Top 20 DE MSE: 0.0173 Validation Top 20 DE MSE: 0.0157.
# Epoch 16 Step 1 Train Loss: 1.1197
# Epoch 16 Step 51 Train Loss: 1.1573
# Epoch 16 Step 101 Train Loss: 1.0591
# Epoch 16 Step 151 Train Loss: 1.1944
# Epoch 16 Step 201 Train Loss: 1.0998
# Epoch 16 Step 251 Train Loss: 1.0437
# Epoch 16 Step 301 Train Loss: 1.1000
# Epoch 16 Step 351 Train Loss: 1.2887
# Epoch 16 Step 401 Train Loss: 0.9876
# Epoch 16 Step 451 Train Loss: 1.2541
# Epoch 16 Step 501 Train Loss: 1.0517
# Epoch 16 Step 551 Train Loss: 0.9412
# Epoch 16: Train Overall MSE: 0.0041 Validation Overall MSE: 0.0042.
# Train Top 20 DE MSE: 0.0173 Validation Top 20 DE MSE: 0.0157.
# Epoch 17 Step 1 Train Loss: 1.0883
# Epoch 17 Step 51 Train Loss: 1.1888
# Epoch 17 Step 101 Train Loss: 1.1225
# Epoch 17 Step 151 Train Loss: 1.1373
# Epoch 17 Step 201 Train Loss: 1.0319
# Epoch 17 Step 251 Train Loss: 1.0365
# Epoch 17 Step 301 Train Loss: 1.1181
# Epoch 17 Step 351 Train Loss: 1.0956
# Epoch 17 Step 401 Train Loss: 1.0660
# Epoch 17 Step 451 Train Loss: 1.2071
# Epoch 17 Step 501 Train Loss: 1.1506
# Epoch 17 Step 551 Train Loss: 1.1919
# Epoch 17: Train Overall MSE: 0.0041 Validation Overall MSE: 0.0042.
# Train Top 20 DE MSE: 0.0173 Validation Top 20 DE MSE: 0.0157.
# Epoch 18 Step 1 Train Loss: 1.1350
# Epoch 18 Step 51 Train Loss: 1.1058
# Epoch 18 Step 101 Train Loss: 1.0425
# Epoch 18 Step 151 Train Loss: 1.1192
# Epoch 18 Step 201 Train Loss: 1.0488
# Epoch 18 Step 251 Train Loss: 1.1831
# Epoch 18 Step 301 Train Loss: 1.1249
# Epoch 18 Step 351 Train Loss: 1.0014
# Epoch 18 Step 401 Train Loss: 1.0405
# Epoch 18 Step 451 Train Loss: 1.0901
# Epoch 18 Step 501 Train Loss: 1.1409
# Epoch 18 Step 551 Train Loss: 1.2075
# Epoch 18: Train Overall MSE: 0.0041 Validation Overall MSE: 0.0042.
# Train Top 20 DE MSE: 0.0173 Validation Top 20 DE MSE: 0.0157.
# Epoch 19 Step 1 Train Loss: 1.1127
# Epoch 19 Step 51 Train Loss: 1.0839
# Epoch 19 Step 101 Train Loss: 1.1852
# Epoch 19 Step 151 Train Loss: 1.0529
# Epoch 19 Step 201 Train Loss: 1.1383
# Epoch 19 Step 251 Train Loss: 1.0662
# Epoch 19 Step 301 Train Loss: 1.0234
# Epoch 19 Step 351 Train Loss: 1.1556
# Epoch 19 Step 401 Train Loss: 1.1185
# Epoch 19 Step 451 Train Loss: 1.2225
# Epoch 19 Step 501 Train Loss: 1.0719
# Epoch 19 Step 551 Train Loss: 1.0926
# Epoch 19: Train Overall MSE: 0.0041 Validation Overall MSE: 0.0042.
# Train Top 20 DE MSE: 0.0173 Validation Top 20 DE MSE: 0.0157.
# Epoch 20 Step 1 Train Loss: 1.0997
# Epoch 20 Step 51 Train Loss: 1.1110
# Epoch 20 Step 101 Train Loss: 1.0884
# Epoch 20 Step 151 Train Loss: 1.1418
# Epoch 20 Step 201 Train Loss: 1.1370
# Epoch 20 Step 251 Train Loss: 1.0994
# Epoch 20 Step 301 Train Loss: 1.0818
# Epoch 20 Step 351 Train Loss: 1.2446
# Epoch 20 Step 401 Train Loss: 1.0290
# Epoch 20 Step 451 Train Loss: 1.1050
# Epoch 20 Step 501 Train Loss: 1.1228
# Epoch 20 Step 551 Train Loss: 1.0759
# Epoch 20: Train Overall MSE: 0.0041 Validation Overall MSE: 0.0042.
# Train Top 20 DE MSE: 0.0173 Validation Top 20 DE MSE: 0.0157.
# Done!
# Start Testing...
# Best performing model: Test Top 20 DE MSE: 0.0212
# Done!

# %%
predictable_test_perturbations = [
    p for p in test_perturbations
    if p in gears_model.pert_list
]

missing_test_perturbations = [
    p for p in test_perturbations
    if p not in gears_model.pert_list
]

print("Original test perturbations:", len(test_perturbations))
print("Predictable test perturbations:", len(predictable_test_perturbations))
print("Missing from GEARS graph:", len(missing_test_perturbations))
# Out:
# Original test perturbations: 53
# Predictable test perturbations: 40
# Missing from GEARS graph: 13

# %% [markdown]
# ## 6. Predict on test perturbations

# %%
test_input = [[p] for p in predictable_test_perturbations]

predictions = gears_model.predict(test_input)

print("Number of predictions:", len(predictions))
print("Example keys:", list(predictions.keys())[:10])
# Out:
# Number of predictions: 40
# Example keys: ['CTSB', 'TGFB1', 'DDR1', 'TPRKB', 'CHCHD2', 'IDH2', 'RRS1', 'UBC', 'PFDN4', 'ISYNA1']

# %%
# GEARS predictions
gears_pred_dict = {}

for pert in predictable_test_perturbations:
    gears_pred_dict[pert] = predictions[pert]

# Average perturbation baseline
avg_pred_dict = {}

for pert in predictable_test_perturbations:
    avg_pred_dict[pert] = reference

# Ground truth
truth_dict = {}

for pert in predictable_test_perturbations:
    truth_dict[pert] = ground_truth_centroids.loc[pert].values

print("GEARS predictions:", len(gears_pred_dict))
print("Baseline predictions:", len(avg_pred_dict))
print("Ground truths:", len(truth_dict))
# Out:
# GEARS predictions: 40
# Baseline predictions: 40
# Ground truths: 40

# %% [markdown]
# ## 7. Evaluation
#
# GEARS was evaluated on the held-out test perturbations. Due to limitations of the perturbation graph, predictions could be generated for 40 of the 53 test perturbations. All evaluation metrics were therefore computed on these 40 predictable perturbations.
#
# The average perturbation baseline was defined as the mean centroid of all training perturbations and was used as a constant baseline prediction. The same vector was used as the reference for PearsonΔ calculations.

# %%
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error
import numpy as np
import pandas as pd

# ----------------------------
# Per-perturbation metrics
# ----------------------------
rows = []

for pert in predictable_test_perturbations:

    y_true = truth_dict[pert]
    y_gears = gears_pred_dict[pert]
    y_avg = avg_pred_dict[pert]

    rows.append({
        "perturbation": pert,
        "gears_rmse": np.sqrt(mean_squared_error(y_true, y_gears)),
        "avg_rmse": np.sqrt(mean_squared_error(y_true, y_avg)),
        "gears_pearson": pearsonr(y_true, y_gears)[0],
        "avg_pearson": pearsonr(y_true, y_avg)[0],
        "gears_pearson_delta": pearsonr(
            y_true - reference,
            y_gears - reference
        )[0]
    })

results_df = pd.DataFrame(rows)


# ----------------------------
# Centroid accuracy
# ----------------------------
def centroid_accuracy(pred_dict, truth_dict):
    perts = list(pred_dict.keys())
    scores = []

    for p in perts:
        d_correct = np.linalg.norm(pred_dict[p] - truth_dict[p])

        d_others = [
            np.linalg.norm(pred_dict[p] - truth_dict[q])
            for q in perts
            if q != p
        ]

        scores.append(np.mean([d_correct < d for d in d_others]))

    return np.mean(scores)


# ----------------------------
# Aggregate summary table
# ----------------------------
summary_table = pd.DataFrame({
    "GEARS": {
        "RMSE": results_df["gears_rmse"].mean(),
        "Pearson (raw)": results_df["gears_pearson"].mean(),
        "Pearson (delta)": results_df["gears_pearson_delta"].mean(),
        "Centroid accuracy": centroid_accuracy(gears_pred_dict, truth_dict)
    },
    "Average perturbation baseline": {
        "RMSE": results_df["avg_rmse"].mean(),
        "Pearson (raw)": results_df["avg_pearson"].mean(),
        "Pearson (delta)": np.nan,
        "Centroid accuracy": centroid_accuracy(avg_pred_dict, truth_dict)
    }
})

print("=== Aggregate summary ===")
display(summary_table.round(4))


# ----------------------------
# Top 15 perturbations by GEARS Pearson
# ----------------------------
top15_table = (
    results_df
    .sort_values("gears_pearson", ascending=False)
    [
        [
            "perturbation",
            "gears_rmse",
            "avg_rmse",
            "gears_pearson",
            "avg_pearson",
            "gears_pearson_delta"
        ]
    ]
    .head(15)
    .round(4)
)

print("=== Top 15 perturbations by GEARS Pearson ===")
display(top15_table)
# Out:
# === Aggregate summary ===
#                     GEARS  Average perturbation baseline
# RMSE               0.0586                         0.0509
# Pearson (raw)      0.9882                         0.9905
# Pearson (delta)    0.0070                            NaN
# Centroid accuracy  0.5051                         0.5000
# === Top 15 perturbations by GEARS Pearson ===
#    perturbation  gears_rmse  avg_rmse  gears_pearson  avg_pearson  \
# 8         PFDN4      0.0421    0.0348         0.9945       0.9962
# 5          IDH2      0.0426    0.0339         0.9943       0.9965
# 25        SP100      0.0437    0.0372         0.9941       0.9958
# 1         TGFB1      0.0439    0.0344         0.9940       0.9963
# 20         TP53      0.0444    0.0356         0.9938       0.9961
# 24         KLF4      0.0450    0.0367         0.9937       0.9958
# 21        VDAC2      0.0450    0.0368         0.9936       0.9957
# 4        CHCHD2      0.0454    0.0351         0.9936       0.9962
# 33       RNF213      0.0465    0.0367         0.9934       0.9958
# 27        SDCBP      0.0463    0.0366         0.9934       0.9958
# 29         WBP2      0.0462    0.0369         0.9934       0.9958
# 10          AGA      0.0466    0.0372         0.9933       0.9957
# 38         SDC3      0.0477    0.0382         0.9931       0.9955
# 19       LRPAP1      0.0474    0.0389         0.9930       0.9953
# 2          DDR1      0.0472    0.0388         0.9930       0.9953
#
#     gears_pearson_delta
# 8                0.0896
# 5                0.0347
# 25               0.0610
# 1                0.0004
# 20              -0.0042
# 24               0.0398
# 21               0.0249
# 4               -0.0422
# 33              -0.0020
# 27               0.0367
# 29               0.0166
# 10               0.0091
# 38              -0.0033
# 19              -0.0075
# 2                0.0163

# %%
import matplotlib.pyplot as plt
import seaborn as sns
  
top15_perts = top15_table["perturbation"].tolist()

top15_metrics = results_df[
    results_df["perturbation"].isin(top15_perts)
].set_index("perturbation").loc[top15_perts]

rmse_heatmap = top15_metrics[
    ["gears_rmse", "avg_rmse"]
].rename(columns={
    "gears_rmse": "GEARS",
    "avg_rmse": "Average perturbation baseline"
})

plt.figure(figsize=(6, 8))
sns.heatmap(rmse_heatmap, annot=True, fmt=".4f", cmap="Oranges", linewidths=2, linecolor="white")
plt.title("Top 15 perturbations: RMSE")
plt.ylabel("Perturbation")
plt.xlabel("Model")
plt.tight_layout()
plt.show()

pearson_heatmap = top15_metrics[
    ["gears_pearson", "avg_pearson"]
].rename(columns={
    "gears_pearson": "GEARS",
    "avg_pearson": "Average perturbation baseline"
})

plt.figure(figsize=(6, 8))
sns.heatmap(pearson_heatmap, annot=True, fmt=".4f", cmap="GnBu", linewidths=2, linecolor="white")
plt.title("Top 15 perturbations: Pearson correlation")
plt.ylabel("Perturbation")
plt.xlabel("Model")
plt.tight_layout()
plt.show()

pearson_delta_heatmap = top15_metrics[
    ["gears_pearson_delta"]
].rename(columns={
    "gears_pearson_delta": "GEARS"
})

plt.figure(figsize=(4, 8))
sns.heatmap(pearson_delta_heatmap, annot=True, fmt=".4f", cmap="GnBu", linewidths=2, linecolor="white")
plt.title("Top 15 perturbations: Pearson delta")
plt.ylabel("Perturbation")
plt.xlabel("Model")
plt.tight_layout()
plt.show()

# %%
PALETTE = {
    "GEARS": "#1f77b4",
    "Average perturbation baseline": "#ff7f0e"
}

def slim_barplot(ax, data, x, y, palette, title, ylabel):
    sns.barplot(data=data, x=x, y=y, palette=palette, ax=ax)

    for bar in ax.patches:
        w = bar.get_width()
        bar.set_width(w * 0.7)
        bar.set_x(bar.get_x() + w * 0.15)

    ymax = data[y].dropna().max()
    ax.set_ylim(0, ymax * 1.15)

    for c in ax.containers:
        ax.bar_label(c, fmt="%.4f", padding=3)

    ax.set_title(title)
    ax.set_ylabel(ylabel)
    ax.set_xlabel("")


summary_long = (
    summary_table.T
    .reset_index()
    .rename(columns={"index": "model"})
)

# ----------------------------
# RMSE, Pearson, Centroid Accuracy
# ----------------------------
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for ax, metric, ylabel in zip(
    axes,
    ["RMSE", "Pearson (raw)", "Centroid accuracy"],
    ["RMSE", "Pearson r", "Accuracy"]
):
    slim_barplot(
        ax,
        summary_long,
        x="model",
        y=metric,
        palette=PALETTE,
        title=metric,
        ylabel=ylabel
    )

plt.suptitle(
    "Aggregate metrics — Frangieh control dataset",
    fontsize=13,
    y=1.02
)

plt.tight_layout()
plt.show()


# ----------------------------
# Pearson delta (GEARS only)
# ----------------------------
gears_only = summary_long[
    summary_long["model"] == "GEARS"
]

fig, ax = plt.subplots(figsize=(4, 5))

slim_barplot(
    ax,
    gears_only,
    x="model",
    y="Pearson (delta)",
    palette={"GEARS": "#1f77b4"},
    title="Pearson (delta) — GEARS only",
    ylabel="Pearson r (delta)"
)

plt.tight_layout()
plt.show()
